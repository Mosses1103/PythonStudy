# %% [markdown]
# # 6주차_선형회귀분석_문제

# %% [markdown]
# ## 모듈 불러오기

# %%
from IPython.display import display, HTML

# 데이터 전처리 패키지
import numpy as np
import pandas as pd

# 기계학습 모델 구축 및 성능 평가 패키지
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve

# 데이터 시각화 패키지
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# 한글 폰트 설정
plt.rc('font', family='Malgun Gothic')

# %% [markdown]
# ## 데이터 불러오기
#
# ### 배달의 민족
# ### 배달 거리당 배달 시간을 예측하기 위한 예측모델 학습

# %%
bedal = np.array([[100, 20], 
		[150, 24], 
		[300, 36], 
		[400, 47], 
		[130, 22], 
		[240, 32],
		[350, 47], 
		[200, 42], 
		[100, 21], 
		[110, 21], 
		[190, 30], 
		[120, 25], 
		[130, 18], 
		[270, 38], 
		[255, 28]])

# %%
nam = ['Distance', 'Time']

# %%
data = pd.DataFrame(bedal, columns=nam)

# %%
display(data)
# Out:
#     Distance  Time
# 0        100    20
# 1        150    24
# 2        300    36
# 3        400    47
# 4        130    22
# 5        240    32
# 6        350    47
# 7        200    42
# 8        100    21
# 9        110    21
# 10       190    30
# 11       120    25
# 12       130    18
# 13       270    38
# 14       255    28

# %% [markdown]
# ## 데이터 전처리하기

# %% [markdown]
# ### 2. 학습 데이터와 테스트 데이터로 분리

# %%
train_data, test_data = train_test_split(---------------------------------------)

# %% [markdown]
# ## 모델링

# %% [markdown]
# ### 학습 데이터를 이용하여 선형회귀모델 학습

# %%
lm = sm.OLS(-----------------------------------------)
lm_trained = lm.fit()

# %% [markdown]
# ### 모델 학습 결과 (Summary) 확인

# %%
lm_trained.summary()

# %% [markdown]
# ## 예측성능 평가

# %% [markdown]
# ### 1. 학습 데이터셋에 대한 예측성능 평가
# MSE, RMSE 계산하여 성능 확인

# %%
train_data.head()

# %%
train_pred = lm_trained.predict(---------------------------) # 써주세요!

print('Training MSE: {:.3f}'.format(mean_squared_error(-----------------------------)
print('Training RMSE: {:.3f}'.format(np.sqrt(mean_squared_error(------------------------------)

# %% [markdown]
# ### 2. 테스트 데이터셋에 대한 예측성능 평가
# MSE, RMSE 계산하여 성능 확인

# %%
test_data.head()

# %%
test_pred = lm_trained.predict(test_data.drop(['Time'], axis=1)) # 써주세요!

print('Testing MSE: {:.3f}'.format(mean_squared_error(--------------------------------------)
print('Training RMSE: {:.3f}'.format(np.sqrt(mean_squared_error(-------------------------------------)

# %% [markdown]
# ## 결과 출력

# %%
plt.scatter(------------------------------) # 써주세요!
plt.xlabel("Distance")
plt.ylabel("Time")
plt.title("Bedal")
plt.show()

# %%
plt.scatter(--------------------------------------) # 써주세요!
plt.xlabel("Distance")
plt.ylabel("Time")
plt.title("Bedal")
plt.show()

# %% [markdown]
# ## 원하는 Input 넣어보기

# %%
myInput = pd.DataFrame(
    {
     "Distance": [1000]
    }
)
myInput.head()

# %%
my_pred = lm_trained.predict(myInput['Distance']) # 써주세요!
print('예측 소요시간 : {:.1f}'.format(my_pred[0]),'분')
